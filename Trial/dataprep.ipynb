# %%
import pandas as pd
import numpy as nd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("datasets/testset1(hotelName,PriceEtc).csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   S.No.           1212 non-null   int64
#  1   State           1212 non-null   object
#  2   City            1212 non-null   object
#  3   Category        1212 non-null   object
#  4   Alcohol         1212 non-null   object
#  5   Hotel Name      1212 non-null   object
#  6   Address         1212 non-null   object
#  7   Start Date      1212 non-null   object
#  8   Expiry Date     1212 non-null   object
#  9   Total Rooms     1212 non-null   int64
#  10  Room price/day  1212 non-null   int64
# dtypes: int64(3), object(8)
# memory usage: 104.3+ KB

# %%
from sklearn.model_selection import train_test_split
x = data.drop(['Room price/day'], axis=1)
y = data['Room price/day']

# %%
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size= 0.2)

# %%
train_data = x_train.join(y_train)
train_data
train_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'S.No.'}>,
#         <Axes: title={'center': 'Total Rooms'}>],
#        [<Axes: title={'center': 'Room price/day'}>, <Axes: >]],
#       dtype=object)
